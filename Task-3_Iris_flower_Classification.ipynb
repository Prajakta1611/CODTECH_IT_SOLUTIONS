# %% [markdown]
# # Iris Flower Classification

# %% [markdown]
# loading Data set

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df= pd.read_csv("D:\Internship_Project\Iris\Iris.csv")

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.shape
# Out:
# (150, 6)

# %% [markdown]
# # Data cleaning and Model Building

# %%
df.drop(["Id"],inplace=True,axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   SepalLengthCm  150 non-null    float64
#  1   SepalWidthCm   150 non-null    float64
#  2   PetalLengthCm  150 non-null    float64
#  3   PetalWidthCm   150 non-null    float64
#  4   Species        150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df.isnull().sum()
# Out:
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
df.describe()
# Out:
#        SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count     150.000000    150.000000     150.000000    150.000000
# mean        5.843333      3.054000       3.758667      1.198667
# std         0.828066      0.433594       1.764420      0.763161
# min         4.300000      2.000000       1.000000      0.100000
# 25%         5.100000      2.800000       1.600000      0.300000
# 50%         5.800000      3.000000       4.350000      1.300000
# 75%         6.400000      3.300000       5.100000      1.800000
# max         7.900000      4.400000       6.900000      2.500000

# %% [markdown]
# # Data Visualization

# %%
df["Species"].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
df["Species"].value_counts()
# Out:
# Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %%
iris = df[df["Species"]=="Iris-setosa"]
iris
# Out:
#     SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0             5.1           3.5            1.4           0.2  Iris-setosa
# 1             4.9           3.0            1.4           0.2  Iris-setosa
# 2             4.7           3.2            1.3           0.2  Iris-setosa
# 3             4.6           3.1            1.5           0.2  Iris-setosa
# 4             5.0           3.6            1.4           0.2  Iris-setosa
# 5             5.4           3.9            1.7           0.4  Iris-setosa
# 6             4.6           3.4            1.4           0.3  Iris-setosa
# 7             5.0           3.4            1.5           0.2  Iris-setosa
# 8             4.4           2.9            1.4           0.2  Iris-setosa
# 9             4.9           3.1            1.5           0.1  Iris-setosa
# 10            5.4           3.7            1.5           0.2  Iris-setosa
# 11            4.8           3.4            1.6           0.2  Iris-setosa
# ...

# %%
versic = df[df["Species"]=="Iris-versicolor"]
versic
# Out:
#     SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm          Species
# 50            7.0           3.2            4.7           1.4  Iris-versicolor
# 51            6.4           3.2            4.5           1.5  Iris-versicolor
# 52            6.9           3.1            4.9           1.5  Iris-versicolor
# 53            5.5           2.3            4.0           1.3  Iris-versicolor
# 54            6.5           2.8            4.6           1.5  Iris-versicolor
# 55            5.7           2.8            4.5           1.3  Iris-versicolor
# 56            6.3           3.3            4.7           1.6  Iris-versicolor
# 57            4.9           2.4            3.3           1.0  Iris-versicolor
# 58            6.6           2.9            4.6           1.3  Iris-versicolor
# 59            5.2           2.7            3.9           1.4  Iris-versicolor
# 60            5.0           2.0            3.5           1.0  Iris-versicolor
# ...

# %%
verginica = df[df["Species"]=="Iris-virginica"]
verginica
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 100            6.3           3.3            6.0           2.5  Iris-virginica
# 101            5.8           2.7            5.1           1.9  Iris-virginica
# 102            7.1           3.0            5.9           2.1  Iris-virginica
# 103            6.3           2.9            5.6           1.8  Iris-virginica
# 104            6.5           3.0            5.8           2.2  Iris-virginica
# 105            7.6           3.0            6.6           2.1  Iris-virginica
# 106            4.9           2.5            4.5           1.7  Iris-virginica
# 107            7.3           2.9            6.3           1.8  Iris-virginica
# 108            6.7           2.5            5.8           1.8  Iris-virginica
# 109            7.2           3.6            6.1           2.5  Iris-virginica
# 110            6.5           3.2            5.1           2.0  Iris-virginica
# ...

# %%
plt.scatter(iris["SepalLengthCm"],iris["SepalWidthCm"],label="Iris")
plt.scatter(versic["SepalLengthCm"],versic["SepalWidthCm"],label="versicolor")
plt.scatter(verginica["SepalLengthCm"],verginica["SepalWidthCm"],label="virginica")
plt.title("Sepal")
plt.legend()
plt.show()

# %%
plt.scatter(iris["PetalLengthCm"],iris["PetalWidthCm"],label="Iris")
plt.scatter(versic["PetalLengthCm"],versic["PetalWidthCm"],label="versicolor")
plt.scatter(verginica["PetalLengthCm"],verginica["PetalWidthCm"],label="virginica")
plt.title("Petal")
plt.legend()
plt.show()

# %%
df.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# # Encoding The text

# %%
X = df.drop(["Species"],axis=1)

# %%
y = df.Species

# %%
from sklearn.preprocessing import LabelEncoder
encode = LabelEncoder()

# %%
y = encode.fit_transform(y)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

# %%
X_train.shape
# Out:
# (120, 4)

# %%
X_test.shape
# Out:
# (30, 4)

# %% [markdown]
# # Classification model using GaussianNB

# %%
from sklearn.naive_bayes import GaussianNB

# %%
gnb = GaussianNB()

# %%
gnb.fit(X_train,y_train)
# Out:
# GaussianNB()

# %%
gnb.score(X_test,y_test)
# Out:
# 1.0

# %%
gnb_pred = gnb.predict(X_test)
gnb_pred
# Out:
# array([1, 0, 2, 1, 1, 0, 1, 2, 1, 1, 2, 0, 0, 0, 0, 1, 2, 1, 1, 2, 0, 2,
#        0, 2, 2, 2, 2, 2, 0, 0])

# %%
y_test
# Out:
# array([1, 0, 2, 1, 1, 0, 1, 2, 1, 1, 2, 0, 0, 0, 0, 1, 2, 1, 1, 2, 0, 2,
#        0, 2, 2, 2, 2, 2, 0, 0])

# %% [markdown]
# # Classification model using LogisticRegression

# %%
from sklearn.linear_model import LogisticRegression

# %%
lg = LogisticRegression()

# %%
lg.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# # Accuracy

# %%
lg.score(X_test,y_test)
# Out:
# 1.0

# %% [markdown]
# # Predicted value

# %%
pred = lg.predict(X_test)
pred[:10]
# Out:
# array([1, 0, 2, 1, 1, 0, 1, 2, 1, 1])

# %%
y_test[:10]
# Out:
# array([1, 0, 2, 1, 1, 0, 1, 2, 1, 1])

# %% [markdown]
# # Confusion matrix

# %%
from sklearn.metrics import confusion_matrix

# %%
cm = confusion_matrix(y_test,pred)

# %%
import seaborn as sns

# %%
sns.heatmap(cm,annot=True)
# Out:
# <Axes: >

# %% [markdown]
# # Report

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test,pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        10
#            1       1.00      1.00      1.00         9
#            2       1.00      1.00      1.00        11
#
#     accuracy                           1.00        30
#    macro avg       1.00      1.00      1.00        30
# weighted avg       1.00      1.00      1.00        30
